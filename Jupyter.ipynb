# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Kimberly Tew** <br>
# Investment Research Analyst

# %% [markdown]
# *I am interested in Data Science because it is enable a systematic and scientific ways in deriving business strategy from huge data source.*

# %% [markdown]
# ### 1 + 1 = 2

# %%
1+1
# Out:
# 2

# %% [markdown]
# ***

# %% [markdown]
# * bullet item 1
# * bullet item 2

# %% [markdown]
# ![ngsinyu.jpeg](attachment:c58d9acf-8d50-46fc-aa74-3b43ca6611dd.jpeg)

# %% [markdown]
# | Column 1| Column 2|
# |---|---|
# | Row 2| Row 2|
# | Row 3|Row 3|
